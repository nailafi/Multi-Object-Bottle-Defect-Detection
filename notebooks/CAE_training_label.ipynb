# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.68-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.68-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.68 ultralytics-thop-2.0.20

# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = '/content/drive/MyDrive/CAE_dataset_training/dataset_label_training'

# %%
def load_data(folder_path, img_size=128):
    data = []
    for filename in os.listdir(folder_path):
        path = os.path.join(folder_path, filename)
        img = load_img(path, target_size=(img_size, img_size)) #load img
        img = img_to_array(img) #convert array
        img = img / 255.0 #normalisasi 0-1
        data.append(img)
    return np.array(data)

# %%
#split data
X = load_data(folder_path)
X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)

print(f'Data Training: {len(X_train)} | Data Validasi: {len(X_val)}')
# Out:
# Data Training: 564 | Data Validasi: 141

# %%
#arsitektur

input_img = layers.Input(shape=(128, 128, 3))

#ENCODER
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x) #hasil: 64x64x64

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x) #hasil: 32x32x32

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x) #hasil Latent: 16x16x16

#latent 16x16x16 = 4.096 angka

#DECODER
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x) #hasil: 32x32x16

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x) #hasil: 64x64x32

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x) #hasil: 128x128x64

decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

#model
autoencoder = models.Model(input_img, decoded)

#optimizer, learning rate
autoencoder.compile(optimizer=Adam(learning_rate=0.0005), loss='mse')

autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 3)    │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,067 (203.39 KB)
#  Trainable params: 52,067 (203.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#early stop
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

#training
history = autoencoder.fit(
    X_train, X_train,
    epochs=250,
    batch_size=32,
    shuffle=True,
    validation_data=(X_val, X_val),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 502ms/step - loss: 0.0429 - val_loss: 0.0337
# Epoch 2/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0322 - val_loss: 0.0301
# Epoch 3/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0268 - val_loss: 0.0205
# Epoch 4/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0175 - val_loss: 0.0155
# Epoch 5/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0137 - val_loss: 0.0124
# Epoch 6/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0116 - val_loss: 0.0111
# Epoch 7/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0102 - val_loss: 0.0099
# Epoch 8/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 9/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 10/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 11/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 12/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 13/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 14/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 15/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 16/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 17/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 18/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 19/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 20/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 21/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 22/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 23/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 24/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 25/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 26/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 27/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 28/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 29/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 30/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 31/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 32/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 33/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 34/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 35/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 36/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 37/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 38/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 39/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 40/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 41/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 42/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 43/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 44/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 45/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 46/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 47/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 48/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 49/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 50/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 51/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 52/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 53/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 54/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 55/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 56/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 57/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 58/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 59/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 60/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 61/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 62/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 63/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 64/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 65/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 66/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 67/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 68/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 69/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 70/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 71/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 72/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 73/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 74/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 75/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 76/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 77/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 78/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 79/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 80/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 81/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 82/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 83/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 84/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 85/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 86/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 87/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 88/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 89/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 90/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 91/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 92/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 93/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 94/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 95/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 96/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 97/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 98/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 99/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 100/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 101/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 102/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 103/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 104/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 105/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 106/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 107/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 108/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 109/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 110/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 111/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 112/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 113/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 114/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 115/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 116/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 117/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 118/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 119/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 120/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 121/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 122/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 123/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 124/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 125/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 126/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 127/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 128/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 129/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 130/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 131/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 132/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 133/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 134/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 135/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 136/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 137/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 138/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 139/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 140/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 141/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 142/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 143/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 144/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 145/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 146/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 147/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 148/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 149/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 150/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 151/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 152/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 153/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 154/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 155/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 156/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 157/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 158/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 159/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 160/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 161/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 162/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 163/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 164/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 165/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 166/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 167/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 168/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 169/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 170/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 171/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 172/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 173/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 174/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0024 - val_loss: 0.0024

# %%
#tampilkan grafik loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss CAE Label')
plt.legend()
plt.savefig('grafik_loss_cae.png')
plt.show()

# %%
#testing
#ambil gambar dari data validasi
decoded_imgs = autoencoder.predict(X_val)

n = 5 #tampil 5 contoh
plt.figure(figsize=(10,4))
for i in range(n):
  #gambar asli
  ax = plt.subplot(2, n, i+1)
  plt.imshow(X_val[i])
  plt.title('Original')
  plt.axis('off')

  #gambar rekonstruksi
  ax = plt.subplot(2, n, i + 1 + n)
  plt.imshow(decoded_imgs[i])
  plt.title('Reconstructed')
  plt.axis('off')

plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step

# %%
#save model
autoencoder.save("cae_model_label.keras")

# %%
#download model
from google.colab import files

files.download('cae_model_label.keras')
